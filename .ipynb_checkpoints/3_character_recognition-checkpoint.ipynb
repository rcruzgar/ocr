# %%
import cv2
from pytesseract import pytesseract
import numpy as np
import matplotlib.image as mpimg
import os
import glob, random
import matplotlib.pyplot as plt

home_directory = os.getcwd()

# %%
## Cogemos crops random sobre los que hacer el OCR

'''
Lo ideal sería almacenar este texto en archivos json que se organicen en DynamoDB de AWS,
con campos que se hayan inferido del recuadro de la anotación, la clasificación del documento,
y el tipo de información contenida en el propio texto
'''

file_path_type = [home_directory+"/predicted_crops/*.png"]
for i in range(3):   
    images = glob.glob(random.choice(file_path_type))
    random_image = random.choice(images)
    
    clase = random_image.split('__')[-1].split('.png')[0]
    
    print(random_image)
    print('Clase: ' + clase)
    print('-'*50)
    
    ## La leemeos en blanco y negro
    image = cv2.imread(random_image, cv2.IMREAD_GRAYSCALE)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    ## Aquí pondríamos condicionales para, por ejemplo, extraer el crop de la firma directamente
    ## sin pasarla por OCR
    ## Ejemplo:
    
    '''
    if clase == 'firma':
         mpimg.imsave(home_directory + '/firmas/firma_Nombre.png', image)
    '''
    
    
    # usamos Tesseract para el OCR de la imagen
    text = pytesseract.image_to_string(image)
    print(text)
    plt.figure(figsize = (20,2))
    plt.imshow(image)
    plt.show()
# Out:
# /home/rcruz/PycharmProjects/ocr/predicted_crops/5_120.tar_1805.00218.gz_Belgun_Goertsches_Petrecca_ImageMomentMap_13_ori__paragraph.png
# Clase: paragraph
# --------------------------------------------------
#
#
# uM F. BELGUN, ©. GOERTSCHES, AND D. PETRECCA
#
#
#
# y of equivalent formulations of (J) and also for theit automatic occurence on
# a strict les manifold, see [IG] Section 3).
# /home/rcruz/PycharmProjects/ocr/predicted_crops/6_105.tar_1507.02264.gz_DMDNoiseArXivPlain_v3_6_ori__paragraph.png
# Clase: paragraph
# --------------------------------------------------
# We thus have derived a correction to the bias that is present in the original DMD matrix Am, due t
# the effect of sensor noise, We note that this approximation relies on an accurate knowledge of the nois
# covariance matrix. There are numerous means to estimate noise properties from data, see Pyatykh et al
# (2013), for example. ‘The approximations used in deriving this expression also rely on the magnitude ¢
# the noise being smaller than that of the true data within each non-truncated POD mode. We now stat
# explicitly the algorithm by which we can correct for the effect of sensor noise in the DMD algorithm, whiel
# we refer to as noise-corrected DMD, or ncDMD:
#
# ee eee ee ee
# /home/rcruz/PycharmProjects/ocr/predicted_crops/9_10.tar_1601.04660.gz_civ_15_ori__paragraph.png
# Clase: paragraph
# --------------------------------------------------
# ‘The integrated relations presented in Section hold for
# everssul cunattiad. vekhams ehudiduice otal tan tescins

# %%
'''
Intentemos mejorar la lectura de los caracteres
aplicando filtros a las imágenes
'''

# 2 ejemplos
lista_a_mejorar = ['/home/rcruz/PycharmProjects/ocr/predicted_crops/9_10.tar_1601.04660.gz_civ_15_ori__paragraph.png',
                   '/home/rcruz/PycharmProjects/ocr/predicted_crops/6_101.tar_1408.2391.gz_BridgingCollapse3_6_ori__paragraph.png'            
                   ]

for img_mejora in lista_a_mejorar:

    img = cv2.imread(img_mejora, cv2.IMREAD_GRAYSCALE)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
   
    ret, img = cv2.threshold(img, 190, 255, cv2.THRESH_BINARY)
    # ret, img = cv2.threshold(img, 150, 255,cv2.THRESH_TOZERO)
    
    kernel = np.ones((1,1),np.uint8)
    img = cv2.erode(img,kernel,iterations = 3)
    img = cv2.dilate(img, kernel, iterations=3)

    plt.figure(figsize = (15,2))
    plt.imshow(img)
    plt.show()

    text = pytesseract.image_to_string(img, lang='eng', config='--psm 6')
    print(text)
# Out:
# ‘The integrated relations presented in Section held for
# averared quantities. wilhows consileriae actual one-to-one
# explicitly the following simplified partition fnction 1) 52),
# Za Tray raser,
